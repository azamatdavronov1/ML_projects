# %%
import pandas as pd
df = pd.read_csv("advertising.csv")
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.impute import SimpleImputer

# %%
advertising_features = ["TV", "Radio", "Newspaper"]
X = df[advertising_features]
y = df["Sales"]

# %%
#splitting data into train and test and solving the issues with null values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
imputer = SimpleImputer(strategy='mean')
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# %%
correlation = df.corr()
sns.heatmap(correlation, annot = True, cmap = "coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# MSE: 4.40211829144968
# MAE: 1.3617813502090272
# R2: 0.8601145185017869

# %%
model = Ridge(alpha = 100)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# MSE: 10.18663642859956
# MAE: 2.50547224966083
# R2: 0.6763007154011242

# %%
model = Lasso(alpha = 0.01)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# MSE: 10.186339977124229
# MAE: 2.5054369846184654
# R2: 0.6763101356971322

# %%
X = df[["TV"]]
y = df["Sales"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
imputer = SimpleImputer(strategy='mean')
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

figure = plt.figure()
plt.scatter(X_test, y_test, color = "blue", label = "Test")
plt.plot(X_test, y_pred, color = "red", label = "Predicted")
plt.legend(loc = "upper right")
plt.xlabel("Sotuv")
plt.ylabel("Reklama")
plt.show()

# %%
X = df[["Newspaper"]]
y = df["Sales"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
imputer = SimpleImputer(strategy='mean')
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

figure1 = plt.figure()
plt.scatter(X_test, y_test, color = "blue", label = "Test")
plt.plot(X_test, y_pred, color = "red", label = "Predicted")
plt.legend(loc = "upper right")
plt.show()

# %%
sns.pairplot(df)
plt.suptitle("Pairplot")
plt.show()
